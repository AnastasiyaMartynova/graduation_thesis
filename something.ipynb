# %% [markdown]
# cd "C:\Users\anmrt\Desktop\Useful shit\Диплом\graduation_thesis"

# %% [markdown]
# cd "/mnt/c/Users/anmrt/Desktop/Useful shit/Диплом/graduation_thesis"
# code .

# %% [markdown]
# ollama pull qwen2.5:7b
# ollama run qwen2.5:7b "Привет"
# ollama serve
